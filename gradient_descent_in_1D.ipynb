# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 150

# %%
# Define the function and its derivative
def fxn(x):
    return x**2 + 4*x + 4

def df_deriv(x):
    return 2*x + 4
